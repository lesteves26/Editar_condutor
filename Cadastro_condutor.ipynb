# %%
import selenium
import pandas as pd
from datetime import datetime
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select, WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
def select_option_value_toggle(name, element, driver):
    toggle = Select(driver.find_element(By.XPATH, name))     #NOVO DROP DOWN PODEMOS USAR O NOME DO XPATH AO INVES DE USAR O CAMINHO XPATH
    toggle.select_by_visible_text(element)

# %%
cadastro = pd.read_excel(r'C:\Users\Lucas Esteves Pereir\OneDrive - Cepa Centro de Treinamento Ltda\Documentos\estudo_lucas\JJ - CODIGOS\Cadastro de condutor\cadastro_condutor.xlsx', keep_default_na=False) #caso tenha que preencher N/A EM algum dropbox, colocar keep default na
#cadastro['Id do Gestor'] = cadastro['Id do Gestor'].astype('Int64')
display(cadastro.head())
# Out:
#       Nome                  Sobrenome Academy Região      País  \
# 0   ANDRES    FELIPE ORJUELA CHAPETON  Driver   LA&C  Colômbia
# 1  JULIANA               PARDO TEJADA  Driver   LA&C  Colômbia
# 2   SILVIA           LUCIA LARA GOMEZ  Driver   LA&C  Colômbia
# 3   GERMAN  ARTURO CANTILLO MACKENZIE  Driver   LA&C  Colômbia
# 4    JORGE       EDUARDO GOMEZ CORREA  Driver   LA&C  Colômbia
#
#      Grupo Operacional                        Franquia      Setor  \
# 0      GLOBAL SERVICES  Global Services Bogota Reg Ctr      Sales
# 1  INNOVATIVE MEDICINE                Jan-Cil Colombia      Sales
# 2  INNOVATIVE MEDICINE                Jan-Cil Colombia      Sales
# 3  INNOVATIVE MEDICINE                Jan-Cil Colombia      Sales
# 4  INNOVATIVE MEDICINE                Jan-Cil Colombia  Non sales
#
#    Id da Corporação                      Gestor  Id do Gestor  \
# 0         152311698      MAURICIO AGUDELO FALLA      94001050
# ...

# %%
driver = webdriver.Chrome()
#acessar o fdm
driver.get("https://jnj.cepamobility.com/") 
#driver.find_element(By.XPATH, '//*[@id="inputEmail"]').click()
driver.find_element(By.XPATH, '//*[@id="username"]').send_keys("lesteves@cepamobility.com")
driver.find_element(By.XPATH, '//*[@id="password"]').send_keys("Lesteves01")
driver.find_element(By.XPATH,'//*[@id="kc-login"]').click()

# %%
cadastro.iloc[index, :]
# Out:
# Nome                                          JAMES
# Sobrenome                                   WALDRON
# Academy                                     Manager
# Região                                         LA&C
# País                                       Colômbia
# Grupo Operacional                   GLOBAL SERVICES
# Franquia             Global Services Bogota Reg Ctr
# Setor                                           N/A
# Id da Corporação                              18857
# emea                                            NaN
# na                                              NaN
# Gestor
# Id do Gestor
# Email do gestor
# Email                          jwaldron@its.jnj.com
# Name: 186, dtype: object

# %%
#driver.find_element(By.XPATH,'//*[@id="main-menu"]/li[1]/a').click()  #Condutor
#driver.find_element(By.XPATH,'//*[@id="submenu-1"]/li[1]/a').click() # Gerenciamento


for index, row in cadastro.loc[8: , :].iterrows():

    driver.get('https://jnj.cepamobility.com/layout.jsp?refer=/driver/DriverList.jsp')
    time.sleep(0.8)

    # DADOS PESSOAIS
    driver.find_element(By.XPATH, '//*[@id="main-content"]/div/div/div/div/div[2]/div[2]/div/div[2]/a').click() #Agregar condutor
    time.sleep(0.5)
    select_option_value_toggle('//*[@id="main-content"]/form/div/div/div/div/div[2]/div[1]/div/fieldset/div/span/select', row['Academy'], driver) # SELECIONANDO TIPO DE ACESSO
    time.sleep(0.5)
    driver.find_element(By.XPATH,'//*[@id="main-content"]/form/div/div/div/div/div[2]/div[2]/div[1]/fieldset/div[1]/div/input').send_keys(str(cadastro.loc[index, "Nome"])) #NOME
    driver.find_element(By.XPATH,'//*[@id="main-content"]/form/div/div/div/div/div[2]/div[2]/div[1]/fieldset/div[2]/div/input').send_keys(str(cadastro.loc[index, "Sobrenome"])) #SOBRENOME

    time.sleep(0.8)

    # DADOS DE LOCALIDADES
    select_option_value_toggle('//*[@id="main-content"]/form/div/div/div/div/div[2]/div[2]/div[1]/div[1]/div/select', row['Região'], driver) # REGIÃO DO CONDUTOR
    select_option_value_toggle('//*[@id="main-content"]/form/div/div/div/div/div[2]/div[2]/div[1]/div[2]/div/select', row["País"], driver) # PAÍS DO CONDUTOR

    time.sleep(0.5)
    # DADOS OPERACIONAIS
    select_option_value_toggle('//*[@id="main-content"]/form/div/div/div/div/div[2]/div[2]/div[2]/div[1]/fieldset/div[1]/div/select', row["Grupo Operacional"], driver) # GRUPO OPERACIONAL
    select_option_value_toggle('//*[@id="main-content"]/form/div/div/div/div/div[2]/div[2]/div[2]/div[1]/fieldset/div[2]/div/select', row["Franquia"], driver) # FRANQUIA
    select_option_value_toggle('//*[@id="main-content"]/form/div/div/div/div/div[2]/div[2]/div[2]/div[2]/fieldset/div/div/select', row["Setor"], driver) # SETOR DO CONDUTOR

    time.sleep(0.8)

    # DADOS CORPORATIVO
    driver.find_element(By.XPATH, '//*[@id="main-content"]/form/div/div/div/div/div[2]/div[3]/div[1]/fieldset/div[1]/div/input').send_keys(str(cadastro.loc[index, 'Id da Corporação'])) # WWID
    driver.find_element(By.XPATH, '//*[@id="main-content"]/form/div/div/div/div/div[2]/div[3]/div[1]/fieldset/div[7]/div/input').send_keys(str(cadastro.loc[index, "Email"])) # EMAIL CONDUTOR

    time.sleep(0.8)

    # DADOS DO GESTOR
    select_option_value_toggle('//*[@id="main-content"]/form/div/div/div/div/div[2]/div[3]/div[1]/fieldset/div[2]/div/select', row["Gestor"], driver) # NOME DO GESTOR
    driver.find_element(By.XPATH, '//*[@id="main-content"]/form/div/div/div/div/div[2]/div[3]/div[1]/fieldset/div[3]/div/input').send_keys(str(cadastro.loc[index, 'Id do Gestor'])) # WWID DO GESTOR
    driver.find_element(By.XPATH, '//*[@id="main-content"]/form/div/div/div/div/div[2]/div[3]/div[1]/fieldset/div[4]/div/input').send_keys(str(cadastro.loc[index, 'Email do gestor'])) # EMAIL DO GESTOR
    #driver.find_element(By.XPATH, '//*[@id="main-content"]/form/div/div/div/div/div[2]/div[3]/div[1]/fieldset/div[10]/div/div/label[1]/input').click() # SELECIONADO A OPÇÃO MANAGER SIM OU NAO



    #FINALIZAÇÃO
    driver.find_element(By.XPATH, '//*[@id="main-content"]/form/div/div/div/div/div[2]/div[3]/div[2]/fieldset/div[2]/div/div/textarea').send_keys("Atualização da frota - Sharon - 28/01") # COMENTÁRIO
    driver.find_element(By.XPATH, '//*[@id="main-content"]/form/div/div/div/div/div[2]/div[3]/div[2]/fieldset/div[3]/input[1]').click() #SALVANDO

    
    try:
        print(f"linha {index} Cadastrado - Condutor: {row['Nome']} / ID: {row['Id da Corporação']}")

    except Exception as e:
        print(f"❌ linha {index} NÃO cadastrado - Condutor: {row['Nome']} / ID: {row['Id da Corporação']} / Erro: {e}")
# Out:
# linha 8 Cadastrado - Condutor: JEIMMY / ID: 152306233
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[17], line 39
#      36 time.sleep(0.8)
#      38 # DADOS DO GESTOR
# ---> 39 select_option_value_toggle('//*[@id="main-content"]/form/div/div/div/div/div[2]/div[3]/div[1]/fieldset/div[2]/div/select', row["Gestor"], driver) # NOME DO GESTOR
#      40 driver.find_element(By.XPATH, '//*[@id="main-content"]/form/div/div/div/div/div[2]/div[3]/div[1]/fieldset/div[3]/div/input').send_keys(str(cadastro.loc[index, 'Id do Gestor'])) # WWID DO GESTOR
#      41 driver.find_element(By.XPATH, '//*[@id="main-content"]/form/div/div/div/div/div[2]/div[3]/div[1]/fieldset/div[4]/div/input').send_keys(str(cadastro.loc[index, 'Email do gestor'])) # EMAIL DO GESTOR
#
# Cell In[7], line 13, in select_option_value_toggle(name, element, driver)
# ...
