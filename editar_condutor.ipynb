# %% [markdown]
# ### EDITANDO DADOS DOS CONDUTORES

# %%
import selenium
import pandas as pd
from datetime import datetime
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select, WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
def select_option_value_toggle(name, element, driver):
    toggle = Select(driver.find_element(By.XPATH, name))     #NOVO DROP DOWN PODEMOS USAR O NOME DO XPATH AO INVES DE USAR O CAMINHO XPATH
    toggle.select_by_visible_text(element)

# %%
editar = pd.read_excel(r'C:\Users\Lucas Esteves Pereir\Documents\estudo_lucas\JJ - CODIGOS\Condutor.xlsx')
display(editar)
# Out:
#       id fdm                    gerente
# 0   13474443  J&J Medical Southern Cone
# 1   13474437  J&J Medical Southern Cone
# 2   13474442  J&J Medical Southern Cone
# 3   13474438  J&J Medical Southern Cone
# 4   13474439  J&J Medical Southern Cone
# 5   13474441  J&J Medical Southern Cone
# 6   13474436  J&J Medical Southern Cone
# 7   13474444  J&J Medical Southern Cone
# 8   13474446  J&J Medical Southern Cone
# 9   13474528  J&J Medical Southern Cone
# 10  13475650  J&J Medical Southern Cone
# 11  13474435  J&J Medical Southern Cone
# 12  13474445  J&J Medical Southern Cone

# %%
driver = webdriver.Chrome()
#acessar o fdm
driver.get("https://jnj.cepamobility.com/") 
#driver.find_element(By.XPATH, '//*[@id="inputEmail"]').click()
driver.find_element(By.XPATH, '//*[@id="username"]').send_keys("lesteves@cepamobility.com")
driver.find_element(By.XPATH, '//*[@id="password"]').send_keys("Lesteves01")
driver.find_element(By.XPATH,'//*[@id="kc-login"]').click()

# %%
editar.iloc[index, :]
# Out:
# id fdm                   415529
# gerente        FERNANDA MONTANI
# id                    152961964
# email      FMontani@ITS.JNJ.com
# Name: 132, dtype: object

# %%
#driver.find_element(By.XPATH,'//*[@id="main-menu"]/li[1]/a').click() #clicar em condutor
#driver.find_element(By.XPATH,'//*[@id="submenu-1"]/li[1]/a').click() # gerenciamento

for index, row in editar.loc[1: , :].iterrows():
    driver.get("https://jnj.cepamobility.com/layout.jsp?refer=/driver/DriverView.jsp?id=" + str(row['id fdm']))
    time.sleep(0.5)
    driver.find_element(By.XPATH,'//*[@id="main-content"]/div/div/div/div/div[2]/div[1]/div/div/a[2]').click()
    time.sleep(0.5)
    driver.find_element(By.XPATH, '//*[@id="main-content"]/form[1]/div/div/div/div/div[2]/div[2]/div[1]/div[1]/div/input').send_keys(Keys.CONTROL, "a")
    driver.find_element(By.XPATH, '//*[@id="main-content"]/form[1]/div/div/div/div/div[2]/div[2]/div[1]/div[1]/div/input').send_keys(str(editar.loc[index, "gerente"]))
    # driver.find_element(By.XPATH,'//*[@id="main-content"]/form[1]/div/div/div/div/div[2]/div[2]/div[1]/div[3]/div/input').send_keys(Keys.CONTROL, "a")
    # driver.find_element(By.XPATH, '//*[@id="main-content"]/form[1]/div/div/div/div/div[2]/div[2]/div[1]/div[3]/div/input').send_keys(str(editar.loc[index, "id"])) # Alterar o XPATH para o campo que deseja editar
    # driver.find_element(By.XPATH,'//*[@id="main-content"]/form[1]/div/div/div/div/div[2]/div[2]/div[1]/div[4]/div/input').send_keys(Keys.CONTROL, "a")
    # driver.find_element(By.XPATH, '//*[@id="main-content"]/form[1]/div/div/div/div/div[2]/div[2]/div[1]/div[4]/div/input').send_keys(str(editar.loc[index, "email"]))
    #driver.find_element(By.XPATH, '//*[@id="main-content"]/form[1]/div/div/div/div/div[2]/div[1]/div[1]/div[6]/div/input').send_keys(Keys.CONTROL, "a") # Alterar o XPATH para o campo que deseja editar
    

    #select_option_value_toggle('//*[@id="main-content"]/form[1]/div/div/div/div/div[2]/div[1]/div[3]/div[1]/fieldset/div[2]/div/select', row["gerente"] , driver) #Para editar algum dado em dropdonw - mudar somente o XPATH e o element
    #select_option_value_toggle('//*[@id="main-content"]/form[1]/div/div/div/div/div[2]/div[2]/div[1]/div[3]/div/input', row["id"] , driver)
    #select_option_value_toggle('//*[@id="main-content"]/form[1]/div/div/div/div/div[2]/div[2]/div[1]/div[4]/div/input', row["email"] , driver)
    #driver.find_element(By.XPATH, '').send_keys(str(editar.loc[linha, ""])) caso queria adicionar mais dados para editar
    #driver.find_element(By.XPATH, '').send_keys(str(editar.loc[linha, ""]))
    #driver.find_element(By.XPATH, '').send_keys(str(editar.loc[linha, ""]))
    #driver.find_element(By.XPATH, '').send_keys(str(editar.loc[linha, ""]))
    
    time.sleep(0.5)
    driver.find_element(By.XPATH, '//*[@id="main-content"]/form[1]/div/div/div/div/div[2]/div[2]/div[3]/div/textarea').send_keys("Atualizado por script - Lucas 30/10")
    time.sleep(0.5)
    driver.find_element(By.XPATH, '//*[@id="main-content"]/form[1]/div/div/div/div/div[2]/div[2]/div[4]/div/input[1]').click()
    print(f"Linha {index} - Editado - ID FDM: {row['id fdm']}")
