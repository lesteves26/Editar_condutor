# %% [markdown]
# ### EDITANDO DADOS DOS CONDUTORES

# %%
import selenium
import pandas as pd
from datetime import datetime
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select, WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
def select_option_value_toggle(name, element, driver):
    toggle = Select(driver.find_element(By.XPATH, name))     #NOVO DROP DOWN PODEMOS USAR O NOME DO XPATH AO INVES DE USAR O CAMINHO XPATH
    toggle.select_by_visible_text(element)

# %%
editar = pd.read_excel(r'C:\Users\Lucas Esteves Pereir\OneDrive - Cepa Centro de Treinamento Ltda\Documentos\estudo_lucas\JJ - CODIGOS\Atualização da frota\Condutor\Condutor.xlsx')
display(editar)
# Out:
#     id fdm  Pais  Nome do gestor  id gestor           email gestor
# 0   415562   NaN             NaN   35002592   ccrisost@its.jnj.com
# 1   440145   NaN             NaN   35004718  mcardenas@its.jnj.com
# 2   338701   NaN             NaN   19014444     jquel1@its.jnj.com
# 3   324940   NaN             NaN   35002944   aaguir18@its.jnj.com
# 4   440201   NaN             NaN   35002944   aaguir18@its.jnj.com
# ..     ...   ...             ...        ...                    ...
# 80  262636   NaN             NaN  152308467   pplacido@its.jnj.com
# 81  329842   NaN             NaN  152258159   kschuhw1@its.jnj.com
# 82  447558   NaN             NaN  152207527   aguzma38@its.jnj.com
# 83  440436   NaN             NaN  152306179   dsotosa1@its.jnj.com
# 84  444089   NaN             NaN  152307156   ggiorda1@its.jnj.com
#
# [85 rows x 5 columns]

# %%
driver = webdriver.Chrome()
#acessar o fdm
driver.get("https://jnj.cepamobility.com/") 
#driver.find_element(By.XPATH, '//*[@id="inputEmail"]').click()
driver.find_element(By.XPATH, '//*[@id="username"]').send_keys("lesteves@cepamobility.com")
driver.find_element(By.XPATH, '//*[@id="password"]').send_keys("Lesteves01")
driver.find_element(By.XPATH,'//*[@id="kc-login"]').click()

# %%
editar.iloc[index, :]
# Out:
# id fdm                   13480166
# gestor           GUILHERME MENDES
# id gestor               152934965
# email        GdeMora2@ITS.JNJ.com
# Name: 6, dtype: object

# %%
#driver.find_element(By.XPATH,'//*[@id="main-menu"]/li[1]/a').click() #clicar em condutor
#driver.find_element(By.XPATH,'//*[@id="submenu-1"]/li[1]/a').click() # gerenciamento

for index, row in editar.loc[0: , :].iterrows():
    time.sleep(0.5)
    driver.get("https://jnj.cepamobility.com/layout.jsp?refer=/driver/DriverView.jsp?id=" + str(int(row['id fdm'])))
    time.sleep(0.5)
    driver.find_element(By.XPATH,'//*[@id="main-content"]/div/div/div/div/div[2]/div[1]/div/div/a[2]').click() #editar
    time.sleep(0.5)
    #driver.find_element(By.XPATH, '//*[@id="main-content"]/form/div/div/div/div/div[2]/div[2]/div[1]/div[9]/div/div/label[1]/input').click()

    #select_option_value_toggle('//*[@id="main-content"]/form/div/div/div/div/div[2]/div[2]/div[1]/div[2]/div/select', row['Nome do gestor'], driver)
    driver.find_element(By.XPATH,'//*[@id="main-content"]/form/div/div/div/div/div[2]/div[2]/div[1]/div[3]/div/input').send_keys(Keys.CONTROL, "a")
    driver.find_element(By.XPATH, '//*[@id="main-content"]/form/div/div/div/div/div[2]/div[2]/div[1]/div[3]/div/input').send_keys(str(editar.loc[index, "id gestor"])) # Alterar o XPATH para o campo que deseja editar
    driver.find_element(By.XPATH,'//*[@id="main-content"]/form/div/div/div/div/div[2]/div[2]/div[1]/div[4]/div/input').send_keys(Keys.CONTROL, "a")
    driver.find_element(By.XPATH, '//*[@id="main-content"]/form/div/div/div/div/div[2]/div[2]/div[1]/div[4]/div/input').send_keys(str(editar.loc[index, "email gestor"]))
    #driver.find_element(By.XPATH, '//*[@id="main-content"]/form[1]/div/div/div/div/div[2]/div[1]/div[1]/div[6]/div/input').send_keys(Keys.CONTROL, "a") # Alterar o XPATH para o campo que deseja editar
    

    #select_option_value_toggle('//*[@id="main-content"]/form/div/div/div/div/div[2]/div[1]/div[3]/div[1]/fieldset/div[1]/div/select', row["Pais"] , driver) #Para editar algum dado em dropdonw - mudar somente o XPATH e o element
    #select_option_value_toggle('//*[@id="main-content"]/form/div/div/div/div/div[2]/div[1]/div[3]/div[1]/fieldset/div[2]/div/select', row["Nome do gestor"] , driver)
    #select_option_value_toggle('//*[@id="main-content"]/form/div/div/div/div/div[2]/div[1]/div[2]/div[2]/div/select', row["Pais"] , driver)
    #
    # driver.find_element(By.XPATH, '').send_keys(str(editar.loc[linha, ""])) caso queria adicionar mais dados para editar
    #driver.find_element(By.XPATH, '').send_keys(str(editar.loc[linha, ""]))
    #driver.find_element(By.XPATH, '').send_keys(str(editar.loc[linha, ""]))
    #driver.find_element(By.XPATH, '').send_keys(str(editar.loc[linha, ""]))
    
    time.sleep(0.5)
    driver.find_element(By.XPATH, '//*[@id="main-content"]/form[1]/div/div/div/div/div[2]/div[2]/div[3]/div/textarea').send_keys("Atualização de dados de gestores - Workday - 21/01")
    time.sleep(0.5)
    driver.find_element(By.XPATH, '//*[@id="main-content"]/form[1]/div/div/div/div/div[2]/div[2]/div[4]/div/input[1]').click()
    time.sleep(0.5)

    print(f"Linha {index} Gestor {row['Nome do gestor']} atualizado - ID: {row['id fdm']}")
# Out:
# Linha 0 Gestor nan atualizado - ID: 415562
# Linha 1 Gestor nan atualizado - ID: 440145
# Linha 2 Gestor nan atualizado - ID: 338701
# Linha 3 Gestor nan atualizado - ID: 324940
# Linha 4 Gestor nan atualizado - ID: 440201
# Linha 5 Gestor nan atualizado - ID: 446888
# Linha 6 Gestor nan atualizado - ID: 8045
# Linha 7 Gestor nan atualizado - ID: 421995
# Linha 8 Gestor nan atualizado - ID: 309457
# Linha 9 Gestor nan atualizado - ID: 440433
# Linha 10 Gestor nan atualizado - ID: 271694
# Linha 11 Gestor nan atualizado - ID: 395255
# Linha 12 Gestor nan atualizado - ID: 116495
# Linha 13 Gestor nan atualizado - ID: 415554
# Linha 14 Gestor nan atualizado - ID: 385491
# Linha 15 Gestor nan atualizado - ID: 357385
# Linha 16 Gestor nan atualizado - ID: 303869
# Linha 17 Gestor nan atualizado - ID: 296799
# Linha 18 Gestor nan atualizado - ID: 440336
# Linha 19 Gestor nan atualizado - ID: 350387
# Linha 20 Gestor nan atualizado - ID: 326428
# Linha 21 Gestor nan atualizado - ID: 415531
# ...
