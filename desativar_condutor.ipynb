# %% [markdown]
# ### DESATIVAR CONDUTOR

# %%
import selenium
import pyautogui
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import keyboard

# %%
desativar = pd.read_excel(r'C:\Users\Lucas Esteves Pereir\OneDrive - Cepa Centro de Treinamento Ltda\Documentos\estudo_lucas\JJ - CODIGOS\Atualização da frota\Condutor\Condutor.xlsx')
display(desativar)
# Out:
#    id fdm  Pais  Nome do gestor  id gestor  email gestor
# 0  448001   NaN             NaN        NaN           NaN
# 1  440121   NaN             NaN        NaN           NaN
# 2  415543   NaN             NaN        NaN           NaN
# 3  381562   NaN             NaN        NaN           NaN
# 4  442227   NaN             NaN        NaN           NaN
# 5  439726   NaN             NaN        NaN           NaN

# %%
driver = webdriver.Chrome()
#acessar o fdm
driver.get("https://jnj.cepamobility.com/") 
#driver.find_element(By.XPATH, '//*[@id="inputEmail"]').click()
driver.find_element(By.XPATH, '//*[@id="username"]').send_keys("lesteves@cepamobility.com")
driver.find_element(By.XPATH, '//*[@id="password"]').send_keys("Lesteves01")
driver.find_element(By.XPATH,'//*[@id="kc-login"]').click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[3], line 5
#       3 driver.get("https://jnj.cepamobility.com/")
#       4 #driver.find_element(By.XPATH, '//*[@id="inputEmail"]').click()
# ----> 5 driver.find_element(By.XPATH, '//*[@id="username"]').send_keys("lesteves@cepamobility.com")
#       6 driver.find_element(By.XPATH, '//*[@id="password"]').send_keys("Lesteves01")
#       7 driver.find_element(By.XPATH,'//*[@id="kc-login"]').click()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     738     by = By.CSS_SELECTOR
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# ...

# %%
desativar.iloc[index, :]
# Out:
# id fdm          446923
# id gestor            -
# email gestor       NaN
# Name: 30, dtype: object

# %%
#driver.find_element(By.XPATH,'//*[@id="main-menu"]/li[1]/a').click() #clicar em condutor
#driver.find_element(By.XPATH,'//*[@id="submenu-1"]/li[1]/a').click() # gerenciamento

for index, row in desativar.loc[0: , :].iterrows():
    time.sleep(0.5)
    driver.get("https://jnj.cepamobility.com/layout.jsp?refer=/driver/DriverView.jsp?id=" + str(int(row['id fdm'])))
    time.sleep(1)
    driver.find_element(By.XPATH,'//*[@id="main-content"]/div/div/div/div/div[2]/div[1]/div/div/a[3]').click() # CLICAR EM DESATIVAR CONDUTOR
    time.sleep(0.5)
    driver.find_element(By.XPATH,'//*[@id="main-content"]/form/div/div/div/div/div[2]/div[1]/div/div[1]/div/input').send_keys("01/28/2026") #ajustar para a data das exclusão
    driver.find_element(By.XPATH,'//*[@id="main-content"]/form/div/div/div/div/div[2]/div[1]/div/textarea').send_keys("Desativado - Somente manager - 28/01") #ajustar para a data da exclusão
    time.sleep(0.5)
    driver.find_element(By.XPATH,'//*[@id="main-content"]/form/div/div/div/div/div[2]/div[2]/div/input[1]').click()


    print(f"Linha {index} Condutor {row['id fdm']} Desativado")
# Out:
# Linha 0 Condutor 452346.0 Desativado
# Linha 1 Condutor 452347.0 Desativado
# Linha 2 Condutor 452348.0 Desativado
# Linha 3 Condutor 452349.0 Desativado
# Linha 4 Condutor 452350.0 Desativado
# Linha 5 Condutor 452351.0 Desativado
