# %% [markdown]
# ### DESATIVAR CONDUTOR

# %%
import selenium
import pyautogui
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import keyboard

# %%
desativar = pd.read_excel(r'C:\Users\Lucas Esteves Pereir\Documents\estudo_lucas\JJ - CODIGOS\Condutor.xlsx')
display(desativar)
# Out:
#       id fdm  gerente  id  email
# 0     370856      NaN NaN    NaN
# 1     370862      NaN NaN    NaN
# 2     359062      NaN NaN    NaN
# 3     370867      NaN NaN    NaN
# 4   13476204      NaN NaN    NaN
# 5   13476202      NaN NaN    NaN
# 6     370868      NaN NaN    NaN
# 7     370866      NaN NaN    NaN
# 8     371274      NaN NaN    NaN
# 9     370859      NaN NaN    NaN
# 10  13476201      NaN NaN    NaN
# 11    370871      NaN NaN    NaN
# 12    370869      NaN NaN    NaN
# 13    371275      NaN NaN    NaN

# %%
driver = webdriver.Chrome()
#acessar o fdm
driver.get("https://fdmpro.cepasafedrive.com/") 
driver.find_element(By.XPATH, '//*[@id="inputEmail"]').click()
driver.find_element(By.XPATH, '//*[@id="inputEmail"]').send_keys("lesteves")
driver.find_element(By.XPATH, '//*[@id="inputPassword"]').send_keys("Le@020896")
driver.find_element(By.XPATH,'//*[@id="loginForm"]/div[3]/button').click()

# %%
desativar.iloc[index, :]
# Out:
# id fdm    352691
# Name: 24, dtype: int64

# %%
#driver.find_element(By.XPATH,'//*[@id="main-menu"]/li[1]/a').click() #clicar em condutor
#driver.find_element(By.XPATH,'//*[@id="submenu-1"]/li[1]/a').click() # gerenciamento

for index, row in desativar.loc[0: , :].iterrows():
    driver.get("https://fdmpro.cepasafedrive.com/datacenter/layout.jsp?refer=/driver/DriverView.jsp?id=" + str(int(row['id fdm'])))
    driver.find_element(By.XPATH,'//*[@id="main-content"]/div/div/div/div/div[2]/div[1]/div/div/a[3]').click() # CLICAR EM DESATIVAR CONDUTOR
    time.sleep(0.5)
    driver.find_element(By.XPATH,'//*[@id="main-content"]/form/div/div/div/div/div[2]/div[1]/div/div[1]/div/input').send_keys("28/10/2024") #ajustar para a data das exclusão
    driver.find_element(By.XPATH,'//*[@id="main-content"]/form/div/div/div/div/div[2]/div[1]/div/textarea').send_keys("Atualizado por Script - Lucas 28/10") #ajustar para a data da exclusão
    time.sleep(0.5)
    driver.find_element(By.XPATH,'//*[@id="main-content"]/form/div/div/div/div/div[2]/div[2]/div/input[1]').click()
