# %% [markdown]
# ### REATIVAR CONDUTOR

# %%
import selenium
import pyautogui
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import keyboard

# %%
reativar = pd.read_excel(r'C:\Users\Lucas Esteves Pereir\Documents\estudo_lucas\JJ - CODIGOS\Condutor.xlsx')
display(reativar)
# Out:
#       id fdm    gerente  id  email
# 0     328932    1076170 NaN    NaN
# 1     424037  155000749 NaN    NaN
# 2     343558  152908917 NaN    NaN
# 3     320212    1068363 NaN    NaN
# 4     344689  152909280 NaN    NaN
# 5     356855     360182 NaN    NaN
# 6     398684  152245434 NaN    NaN
# 7       6590     340584 NaN    NaN
# 8     370895    1028466 NaN    NaN
# 9     370861    1019421 NaN    NaN
# 10    365923     334720 NaN    NaN
# 11    387965    1069638 NaN    NaN
# 12    358634  152952673 NaN    NaN
# 13    362833    1022211 NaN    NaN
# 14    370900  152992072 NaN    NaN
# 15    424038   52000606 NaN    NaN
# 16    412707     357795 NaN    NaN
# 17    367062     368542 NaN    NaN
# 18    398682   30031319 NaN    NaN
# 19    371721  152998135 NaN    NaN
# 20    262275     343053 NaN    NaN
# 21  13472063  152218153 NaN    NaN
# 22    366330     159493 NaN    NaN

# %%
driver = webdriver.Chrome()
#acessar o fdm
driver.get("https://fdmpro.cepasafedrive.com/") 
driver.find_element(By.XPATH, '//*[@id="inputEmail"]').click()
driver.find_element(By.XPATH, '//*[@id="inputEmail"]').send_keys("lesteves")
driver.find_element(By.XPATH, '//*[@id="inputPassword"]').send_keys("Le@020896")
driver.find_element(By.XPATH,'//*[@id="loginForm"]/div[3]/button').click()

# %%
reativar.iloc[linha, :]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 reativar.iloc[linha, :]
#
# NameError: name 'linha' is not defined

# %%
#driver.find_element(By.XPATH,'//*[@id="main-menu"]/li[1]/a').click() #clicar em condutor
#driver.find_element(By.XPATH,'//*[@id="submenu-1"]/li[1]/a').click() # gerenciamento

for index, row in reativar.loc[0:, :].iterrows():
    driver.get("https://fdmpro.cepasafedrive.com/datacenter/layout.jsp?refer=/driver/DriverView.jsp?id=" + str(int(row['id fdm'])))
    driver.find_element(By.XPATH, '//*[@id="main-content"]/div/div/div/div/div[2]/div[1]/div/div/a[3]').click() # CLICANDO EM REATIVAR
    driver.find_element(By.XPATH, '//*[@id="main-content"]/form/div/div/div/div/div[2]/div[1]/div/textarea').send_keys("Atualizado por script - Lucas 28/10") #Ajustar a data para o dia da reativação
    time.sleep(0.5)
    driver.find_element(By.XPATH, '//*[@id="main-content"]/form/div/div/div/div/div[2]/div[2]/div/input[1]').click() #CLICANDO EM SALVAR
