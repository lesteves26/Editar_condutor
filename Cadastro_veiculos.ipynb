# %%
import selenium
import pandas as pd
from datetime import datetime
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select, WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
def select_option_value_toggle(name, element, driver):
    toggle = Select(driver.find_element(By.XPATH, name))     #NOVO DROP DOWN PODEMOS USAR O NOME DO XPATH AO INVES DE USAR O CAMINHO XPATH
    toggle.select_by_visible_text(element)

# %%
cadastro_veiculo = pd.read_excel(r'C:\Users\Lucas Esteves Pereir\OneDrive - Cepa Centro de Treinamento Ltda\Documentos\estudo_lucas\JJ - CODIGOS\Cadastro de veículos\cadastro_veiculos.xlsx')
display(cadastro_veiculo.head())
# Out:
#    Nome  Sobrenome  Id da Corporação   Placa      Marca  \
# 0   NaN        NaN         152050990  PXT950  Chevrolet
# 1   NaN        NaN            151245  PXZ724    Hyundai
# 2   NaN        NaN         152927659  PXZ725    Hyundai
# 3   NaN        NaN          97000301  PXZ728    Hyundai
# 4   NaN        NaN          84003604  PXZ734    Hyundai
#
#                   Modelo   Ano                      Cor             Chassi
# 0    ONIX NB TURBO LT/AT  2025            BLANCO NIEBLA  9BGEN69K0SG270340
# 1  Tucson HEV LIMITED AT  2026  GRIS ECOLOGICO T. NEGRO  KMHJB811BTU363366
# 2    Kona HEV PREMIUM AT  2026  GRIS ECOLOGICO T. NEGRO  KMHHB811GTU151110
# 3    Kona HEV PREMIUM AT  2026  GRIS ECOLOGICO T. NEGRO  KMHHB811GTU163609
# 4    Kona HEV PREMIUM AT  2026  GRIS ECOLOGICO T. NEGRO  KMHHB811GTU163548

# %%
driver = webdriver.Chrome()
#acessar o fdm
driver.get("https://jnj.cepamobility.com/") 
#driver.find_element(By.XPATH, '//*[@id="inputEmail"]').click()
driver.find_element(By.XPATH, '//*[@id="username"]').send_keys("lesteves@cepamobility.com")
driver.find_element(By.XPATH, '//*[@id="password"]').send_keys("Lesteves01")
driver.find_element(By.XPATH,'//*[@id="kc-login"]').click()

# %%
for index, row in cadastro_veiculo.loc[0: , :].iterrows():

    driver.get('https://jnj.cepamobility.com/layout.jsp?refer=/vehicle/VehicleList.jsp')

    driver.find_element(By.XPATH, '//*[@id="main-menu"]/li[3]/a').click() # CLICANDO EM FROTAS
    driver.find_element(By.XPATH, '//*[@id="submenu-18"]/li[3]/a').click() # CLICANDO EM GERENCIAMENTO DE VEÍCULOS
    driver.find_element(By.XPATH, '//*[@id="main-content"]/div/div/div/div/div[2]/div[2]/div/div[1]/div[2]/a').click() #CLICANDO EM AGREGAR VEICULO
    driver.find_element(By.XPATH, '//*[@id="main-content"]/form/div/div/div/div/div[2]/div/div/div/a[1]').click() # SELECIONANDO VEICULO INDIVIDUAL
    time.sleep(0.5)

    driver.find_element(By.XPATH, '//*[@id="searchForm"]/div[2]/input').send_keys(str(cadastro_veiculo.loc[index, 'Id da Corporação'])) # BUSCANDO WWID
    time.sleep(1)
    driver.find_element(By.XPATH, '//*[@id="searchForm"]/div[4]/button').click() # CLICANDO EM BOTÃO BUSCAR
    time.sleep(0.5)
    driver.find_element(By.XPATH, '//*[@id="main-content"]/div/div/div/div/div[2]/div[2]/div/div[1]/table/tbody/tr/td[1]/a').click() # CLICAND NO CONDUTOR
    time.sleep(0.5)

    # PREENCHENDO DADOS DO VEÍCULO
    select_option_value_toggle('//*[@id="main-content"]/form/div/div/div/div/div[2]/div[2]/div/div/div[1]/div/select', 'Automóvel', driver) #TIPO DO VEICULO
    driver.find_element(By.XPATH,'//*[@id="main-content"]/form/div/div/div/div/div[2]/div[2]/div/div/div[2]/div/input').send_keys(str(cadastro_veiculo.loc[index, 'Placa']))
    time.sleep(1)
    select_option_value_toggle('//*[@id="main-content"]/form/div/div/div/div/div[2]/div[4]/div[1]/div[1]/div/select', row["Marca"], driver)
    driver.find_element(By.XPATH, '//*[@id="main-content"]/form/div/div/div/div/div[2]/div[4]/div[1]/div[2]/div/input').send_keys(str(cadastro_veiculo.loc[index, 'Modelo']))
    driver.find_element(By.XPATH, '//*[@id="main-content"]/form/div/div/div/div/div[2]/div[4]/div[1]/div[3]/div/input').send_keys(str(cadastro_veiculo.loc[index, 'Ano']))
    driver.find_element(By.XPATH, '//*[@id="main-content"]/form/div/div/div/div/div[2]/div[4]/div[1]/div[4]/div/input').send_keys(str(cadastro_veiculo.loc[index, 'Cor']))
    driver.find_element(By.XPATH, '//*[@id="main-content"]/form/div/div/div/div/div[2]/div[4]/div[1]/div[5]/div/input').send_keys(str(cadastro_veiculo.loc[index, 'Chassi']))
    time.sleep(0.5)

    driver.find_element(By.XPATH, '//*[@id="main-content"]/form/div/div/div/div/div[2]/div[9]/div/input[1]').click()

    print(f"Linha {index} Cadastrado - Veículo: {row['Placa']}")
# Out:
# Linha 0 Cadastrado - Veículo: PXT950
# Linha 1 Cadastrado - Veículo: PXZ724
# Linha 2 Cadastrado - Veículo: PXZ725
# Linha 3 Cadastrado - Veículo: PXZ728
# Linha 4 Cadastrado - Veículo: PXZ734
# Linha 5 Cadastrado - Veículo: PXZ744
# Linha 6 Cadastrado - Veículo: PXZ746
# Linha 7 Cadastrado - Veículo: PYO876
# Linha 8 Cadastrado - Veículo: PYT465
# Linha 9 Cadastrado - Veículo: PYT469
# Linha 10 Cadastrado - Veículo: PYW431
# Linha 11 Cadastrado - Veículo: PYW436
# Linha 12 Cadastrado - Veículo: PYW452
# Linha 13 Cadastrado - Veículo: PYW462
# Linha 14 Cadastrado - Veículo: PZL849
