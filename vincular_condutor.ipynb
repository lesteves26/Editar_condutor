# %% [markdown]
# ### VINCULAR CONDUTOR AO VEÍCULO

# %%
import selenium
import pyautogui
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import keyboard
from selenium.webdriver.support.ui import Select, WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
def select_option_value_toggle(xpath, element, driver):
    toggle = Select(driver.find_element(By.XPATH, xpath))
    for index in range(len(toggle.options)):
        if toggle.options[index].text == element:
            break
    time.sleep(0.5)
    toggle.select_by_index(index)

# %%
vincu_condu = pd.read_excel(r'C:\Users\Lucas Esteves Pereir\OneDrive - Cepa Centro de Treinamento Ltda\Documentos\estudo_lucas\JJ - CODIGOS\Atualização da frota\Veículo\Veiculo.xlsx')
display(vincu_condu)
# Out:
#      Placa         Id  Setor
# 0   660330  152313804    NaN
# 1   660765  152277891    NaN
# 2   660779  152314446    NaN
# 3   671722    1020566    NaN
# 4   670392  152964819    NaN
# 5   671741  152957486    NaN
# 6   689481  152306707    NaN
# 7   689477  152306665    NaN
# 8   709108  152311444    NaN
# 9   709109  152049578    NaN
# 10  762925  152305215    NaN
# 11  762926  152306233    NaN
# 12  762928  152311353    NaN

# %%
driver = webdriver.Chrome()
#acessar o fdm
driver.get("https://jnj.cepamobility.com/") 
#driver.find_element(By.XPATH, '//*[@id="inputEmail"]').click()
driver.find_element(By.XPATH, '//*[@id="username"]').send_keys("lesteves@cepamobility.com")
driver.find_element(By.XPATH, '//*[@id="password"]').send_keys("Lesteves01")
driver.find_element(By.XPATH,'//*[@id="kc-login"]').click()

# %%
vincu_condu.iloc[linha, :]
# Out:
# Placa       CKR506
# id       152288715
# Name: 4, dtype: object

# %%
#driver.find_element(By.XPATH,'//*[@id="main-menu"]/li[3]/a').click() #clicar em frotas
#driver.find_element(By.XPATH,'//*[@id="submenu-18"]/li[5]/a').click() # gerenciamento

for index, row in vincu_condu.loc[3: , :].iterrows():
    driver.get("https://jnj.cepamobility.com/layout.jsp?refer=/vehicle/VehicleView.jsp?id=" + str(int(row['Placa'])))
    time.sleep(0.5)
    driver.find_element(By.XPATH,'//*[@id="main-content"]/div/div/div/div/div[2]/div[1]/div/a[2]').click() # designar condutor
    time.sleep(0.5)
    driver.find_element(By.XPATH, '//*[@id="searchForm"]/div[2]/input').send_keys(str(vincu_condu.loc[index, "Id"]))
    driver.find_element(By.XPATH,'//*[@id="searchForm"]/div[4]/button').click() # BUSCAR CONDUTOR
    time.sleep(0.5)
    driver.find_element(By.XPATH,'//*[@id="main-content"]/div/div/div/div/div[2]/div[2]/div/div[1]/table/tbody/tr/td[1]/a').click() #ENTRAR NO CONDUTOR
    driver.find_element(By.XPATH,'//*[@id="main-content"]/form/div/div/div/div/div[2]/div/div[2]/input[1]').click() #SALVAR
    

    print(f"Linha {index} Vinculado - Placa: {row['Placa']} / ID: {row['Id']}")
# Out:
# Linha 3 Vinculado - Placa: 671722.0 / ID: 1020566.0
# Linha 4 Vinculado - Placa: 670392.0 / ID: 152964819.0
# Linha 5 Vinculado - Placa: 671741.0 / ID: 152957486.0
# Linha 6 Vinculado - Placa: 689481.0 / ID: 152306707.0
# Linha 7 Vinculado - Placa: 689477.0 / ID: 152306665.0
# Linha 8 Vinculado - Placa: 709108.0 / ID: 152311444.0
# Linha 9 Vinculado - Placa: 709109.0 / ID: 152049578.0
# Linha 10 Vinculado - Placa: 762925.0 / ID: 152305215.0
# Linha 11 Vinculado - Placa: 762926.0 / ID: 152306233.0
# Linha 12 Vinculado - Placa: 762928.0 / ID: 152311353.0
