# %% [markdown]
# ### DESASSOCIAR E DESATIVAR VEÍCULO

# %%
import selenium
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import keyboard
from selenium.webdriver.support.ui import Select, WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
def select_option_value_toggle(xpath, element, driver):
    toggle = Select(driver.find_element(By.XPATH, xpath))
    for index in range(len(toggle.options)):
        if toggle.options[index].text == element:
            break
    time.sleep(0.5)
    toggle.select_by_index(index)

# %%
desassociar = pd.read_excel(r'C:\Users\Lucas Esteves Pereir\OneDrive - Cepa Centro de Treinamento Ltda\Documentos\estudo_lucas\JJ - CODIGOS\Atualização da frota\Veículo\Veiculo.xlsx')
display(desassociar)
# Out:
#       Placa  Id  Setor
# 0    JWV969 NaN    NaN
# 1    JWY437 NaN    NaN
# 2    JWV989 NaN    NaN
# 3    JXS154 NaN    NaN
# 4    JYK188 NaN    NaN
# 5    KWK485 NaN    NaN
# 6   SWT5B71 NaN    NaN
# 7    FWR249 NaN    NaN
# 8    PTP900 NaN    NaN
# 9    KWN566 NaN    NaN
# 10   KWN576 NaN    NaN
# 11   KWN579 NaN    NaN
# 12   PSZ905 NaN    NaN

# %%
driver = webdriver.Chrome()
#acessar o fdm
driver.get("https://jnj.cepamobility.com/") 
#driver.find_element(By.XPATH, '//*[@id="inputEmail"]').click()
driver.find_element(By.XPATH, '//*[@id="username"]').send_keys("lesteves@cepamobility.com")
driver.find_element(By.XPATH, '//*[@id="password"]').send_keys("Lesteves01")
driver.find_element(By.XPATH,'//*[@id="kc-login"]').click()

# %%
desassociar.iloc[linha, :]
# Out:
# Placa    GEG9743
# id           NaN
# Name: 4, dtype: object

# %%
driver.find_element(By.XPATH, '//*[@id="main-menu"]/li[3]/a').click() #frotas
driver.find_element(By.XPATH, '//*[@id="submenu-18"]/li[3]/a').click() #gerenciamento de veículos

for index, row in desassociar.loc[0:, :].iterrows():

#DESASSOCAIR O CONDUTOR
    driver.find_element(By.XPATH,'//*[@id="searchForm"]/input[3]').send_keys(str(desassociar.loc[index, "Placa"]))
    driver.find_element(By.XPATH, '//*[@id="searchForm"]/div[2]/button').click() #BUSCAR
    driver.find_element(By.XPATH, '//*[@id="main-content"]/div/div/div/div/div[2]/div[2]/div/div[2]/form/table/tbody/tr/td[2]/a').click() # CLICAR NO VEÍCULO
    driver.find_element(By.XPATH, '//*[@id="main-content"]/div/div/div/div/div[2]/div[1]/div/a[2]').click() # CLICAR EM DESASSOCIAR
    driver.find_element(By.XPATH, '//*[@id="main-content"]/form/div/div/div/div/div[2]/div/div[1]/textarea').send_keys("Atualização da frota - 28/01") #INSERIR COMENTARIO
    time.sleep(0.5)
    driver.find_element(By.XPATH, '//*[@id="main-content"]/form/div/div/div/div/div[2]/div/div[2]/input').click()  #SALVAR

    print(f"Linha {index} Desvinculado - Placa: {row['Placa']}")
# Out:
# Linha 0 Desvinculado - Placa: JWV969
# Linha 1 Desvinculado - Placa: JWY437
# Linha 2 Desvinculado - Placa: JWV989
# Linha 3 Desvinculado - Placa: JXS154
# Linha 4 Desvinculado - Placa: JYK188
# Linha 5 Desvinculado - Placa: KWK485
# Linha 6 Desvinculado - Placa: SWT5B71
# Linha 7 Desvinculado - Placa: FWR249
# Linha 8 Desvinculado - Placa: PTP900
# Linha 9 Desvinculado - Placa: KWN566
# Linha 10 Desvinculado - Placa: KWN576
# Linha 11 Desvinculado - Placa: KWN579
# Linha 12 Desvinculado - Placa: PSZ905
